# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import password

# %%
# Load in CSV population data
data = pd.read_csv("Resources/PEP_2017_PEPANNRES_with_ann.csv", encoding='latin-1')
data.head()
# Out:
#              GEO.id GEO.id2         GEO.display-label             rescen42010  \
# 0                Id     Id2                 Geography  April 1, 2010 - Census
# 1  1620000US0100124  100124   Abbeville city, Alabama                    2688
# 2  1620000US0100460  100460  Adamsville city, Alabama                    4522
# 3  1620000US0100484  100484     Addison town, Alabama                     758
# 4  1620000US0100676  100676       Akron town, Alabama                     356
#
#                      resbase42010                                respop72010  \
# 0  April 1, 2010 - Estimates Base  Population Estimate (as of July 1) - 2010
# 1                            2688                                       2684
# 2                            4522                                       4516
# 3                             754                                        751
# 4                             356                                        355
#
#                                  respop72011  \
# 0  Population Estimate (as of July 1) - 2011
# 1                                       2677
# 2                                       4502
# 3                                        751
# 4                                        345
#
#                                  respop72012  \
# 0  Population Estimate (as of July 1) - 2012
# 1                                       2629
# 2                                       4479
# 3                                        744
# 4                                        345
#
#                                  respop72013  \
# 0  Population Estimate (as of July 1) - 2013
# 1                                       2612
# 2                                       4457
# 3                                        743
# 4                                        341
#
#                                  respop72014  \
# 0  Population Estimate (as of July 1) - 2014
# 1                                       2595
# 2                                       4437
# 3                                        740
# 4                                        337
#
#                                  respop72015  \
# 0  Population Estimate (as of July 1) - 2015
# 1                                       2587
# 2                                       4409
# 3                                        734
# 4                                        335
#
#                                  respop72016  \
# 0  Population Estimate (as of July 1) - 2016
# 1                                       2575
# 2                                       4376
# 3                                        734
# 4                                        332
#
#                                  respop72017
# 0  Population Estimate (as of July 1) - 2017
# 1                                       2567
# 2                                       4347
# 3                                        728
# 4                                        332

# %%
# Grab only relevant columns
data_col = data[['GEO.display-label', 'rescen42010', 'respop72017']]
data_col.head()
# Out:
#           GEO.display-label             rescen42010  \
# 0                 Geography  April 1, 2010 - Census
# 1   Abbeville city, Alabama                    2688
# 2  Adamsville city, Alabama                    4522
# 3     Addison town, Alabama                     758
# 4       Akron town, Alabama                     356
#
#                                  respop72017
# 0  Population Estimate (as of July 1) - 2017
# 1                                       2567
# 2                                       4347
# 3                                        728
# 4                                        332

# %%
# Rename columns
data_col.columns = ['Location', '2010_Population', '2017_Population']
data_col.head()
# Out:
#                    Location         2010_Population  \
# 0                 Geography  April 1, 2010 - Census
# 1   Abbeville city, Alabama                    2688
# 2  Adamsville city, Alabama                    4522
# 3     Addison town, Alabama                     758
# 4       Akron town, Alabama                     356
#
#                              2017_Population
# 0  Population Estimate (as of July 1) - 2017
# 1                                       2567
# 2                                       4347
# 3                                        728
# 4                                        332

# %%
# Delete first row
data_col_1 = data_col.drop(data_col.index[0])
data_col_1.head()
# Out:
#                    Location 2010_Population 2017_Population
# 1   Abbeville city, Alabama            2688            2567
# 2  Adamsville city, Alabama            4522            4347
# 3     Addison town, Alabama             758             728
# 4       Akron town, Alabama             356             332
# 5   Alabaster city, Alabama           30352           33202

# %%
# Reset index
data_col_1.reset_index(drop = True, inplace=True)
data_col_1.head()
# Out:
#                    Location 2010_Population 2017_Population
# 0   Abbeville city, Alabama            2688            2567
# 1  Adamsville city, Alabama            4522            4347
# 2     Addison town, Alabama             758             728
# 3       Akron town, Alabama             356             332
# 4   Alabaster city, Alabama           30352           33202

# %%
# Split City column into City aqnd State
data_split = data_col_1["Location"].str.split(" city,| town,", expand = True)
data_split.head(40)
# Out:
#                  0         1
# 0        Abbeville   Alabama
# 1       Adamsville   Alabama
# 2          Addison   Alabama
# 3            Akron   Alabama
# 4        Alabaster   Alabama
# 5      Albertville   Alabama
# 6   Alexander City   Alabama
# 7       Aliceville   Alabama
# 8          Allgood   Alabama
# 9          Altoona   Alabama
# 10       Andalusia   Alabama
# 11        Anderson   Alabama
# 12        Anniston   Alabama
# 13            Arab   Alabama
# 14         Ardmore   Alabama
# 15            Argo   Alabama
# 16          Ariton   Alabama
# 17           Arley   Alabama
# 18         Ashford   Alabama
# 19         Ashland   Alabama
# 20        Ashville   Alabama
# 21          Athens   Alabama
# 22          Atmore   Alabama
# 23         Attalla   Alabama
# 24          Auburn   Alabama
# 25    Autaugaville   Alabama
# 26            Avon   Alabama
# 27          Babbie   Alabama
# 28       Baileyton   Alabama
# 29       Bakerhill   Alabama
# 30           Banks   Alabama
# 31     Bay Minette   Alabama
# 32  Bayou La Batre   Alabama
# 33      Bear Creek   Alabama
# 34        Beatrice   Alabama
# 35       Beaverton   Alabama
# 36            Belk   Alabama
# 37          Benton   Alabama
# 38           Berry   Alabama
# 39        Bessemer   Alabama

# %%
# Insert City and State into data_col_1 dataframe
data_col_1['City'] = data_split[0]
data_col_1['State'] = data_split[1]
data_col_1.head()
# Out:
#                    Location 2010_Population 2017_Population        City  \
# 0   Abbeville city, Alabama            2688            2567   Abbeville
# 1  Adamsville city, Alabama            4522            4347  Adamsville
# 2     Addison town, Alabama             758             728     Addison
# 3       Akron town, Alabama             356             332       Akron
# 4   Alabaster city, Alabama           30352           33202   Alabaster
#
#       State
# 0   Alabama
# 1   Alabama
# 2   Alabama
# 3   Alabama
# 4   Alabama

# %%
# Convert Poppulation Columns to int
data_col_1["2010_Population"] = pd.to_numeric(data_col_1['2010_Population'], errors='coerce')
data_col_1["2017_Population"] = pd.to_numeric(data_col_1['2017_Population'], errors='coerce')
data_col_1.dtypes
# Out:
# Location            object
# 2010_Population    float64
# 2017_Population      int64
# City                object
# State               object
# dtype: object

# %%
# Calculate poppulation change
data_col_1['Delta'] = data_col_1['2017_Population'] - data_col_1['2010_Population']
data_col_1.head()
# Out:
#                    Location  2010_Population  2017_Population        City  \
# 0   Abbeville city, Alabama           2688.0             2567   Abbeville
# 1  Adamsville city, Alabama           4522.0             4347  Adamsville
# 2     Addison town, Alabama            758.0              728     Addison
# 3       Akron town, Alabama            356.0              332       Akron
# 4   Alabaster city, Alabama          30352.0            33202   Alabaster
#
#       State   Delta
# 0   Alabama  -121.0
# 1   Alabama  -175.0
# 2   Alabama   -30.0
# 3   Alabama   -24.0
# 4   Alabama  2850.0

# %%
# Rearrange Columns 
data_cleaned = data_col_1[['City', 'State', '2010_Population', '2017_Population', "Delta"]]
data_cleaned.head()
# Out:
#          City     State  2010_Population  2017_Population   Delta
# 0   Abbeville   Alabama           2688.0             2567  -121.0
# 1  Adamsville   Alabama           4522.0             4347  -175.0
# 2     Addison   Alabama            758.0              728   -30.0
# 3       Akron   Alabama            356.0              332   -24.0
# 4   Alabaster   Alabama          30352.0            33202  2850.0

# %%
data_cleaned.dtypes
# Out:
# City                object
# State               object
# 2010_Population    float64
# 2017_Population      int64
# Delta              float64
# dtype: object

# %%
# Add Positive/Negative Column
def neg_pos(row):
    change = row["Delta"]
    if change >= 0:
        return "Positive"
    else:
        return "Negative"

# %%
data_cleaned["Neg_Pos"]=data_cleaned.apply(neg_pos, axis=1)
data_cleaned.head()
# Out:
#          City     State  2010_Population  2017_Population   Delta   Neg_Pos
# 0   Abbeville   Alabama           2688.0             2567  -121.0  Negative
# 1  Adamsville   Alabama           4522.0             4347  -175.0  Negative
# 2     Addison   Alabama            758.0              728   -30.0  Negative
# 3       Akron   Alabama            356.0              332   -24.0  Negative
# 4   Alabaster   Alabama          30352.0            33202  2850.0  Positive

# %%
# Connect to Local SQL Database
connection = f"root:{password}@localhost/quality_db"
engine = create_engine(f"mysql://{connection}")

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\MySQLdb\__init__.py in Connect(*args, **kwargs)
#      83     from MySQLdb.connections import Connection
# ---> 84     return Connection(*args, **kwargs)
#      85
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\MySQLdb\connections.py in __init__(self, *args, **kwargs)
#     163
# --> 164         super(Connection, self).__init__(*args, **kwargs2)
#     165         self.cursorclass = cursorclass
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-24-2d97e9123e98> in <module>
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2238         """
#    2239
# -> 2240         with self._optional_conn_ctx_manager(connection) as conn:
#    2241             if not schema:
#    2242                 schema = self.dialect.default_schema_name
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2022     def _optional_conn_ctx_manager(self, connection=None):
#    2023         if connection is None:
# -> 2024             with self._contextual_connect() as conn:
#    2025                 yield conn
#    2026         else:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2224         return self._connection_cls(
#    2225             self,
# -> 2226             self._wrap_pool_connect(self.pool.connect, None),
#    2227             close_with_result=close_with_result,
#    2228             **kwargs
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2264             if connection is None:
#    2265                 Connection._handle_dbapi_exception_noconnection(
# -> 2266                     e, dialect, self
#    2267                 )
#    2268             else:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2260         dialect = self.dialect
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#    2264             if connection is None:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     127         if value.__traceback__ is not tb:
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#     131     def u(s):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     451
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#     455     def create_connect_args(self, url):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\MySQLdb\__init__.py in Connect(*args, **kwargs)
#      82     """Factory function for connections.Connection."""
#      83     from MySQLdb.connections import Connection
# ---> 84     return Connection(*args, **kwargs)
#      85
#      86 connect = Connection = Connect
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\MySQLdb\connections.py in __init__(self, *args, **kwargs)
#     162         autocommit = kwargs2.pop('autocommit', False)
#     163
# --> 164         super(Connection, self).__init__(*args, **kwargs2)
#     165         self.cursorclass = cursorclass
#     166         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (MySQLdb._exceptions.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
# (Background on this error at: http://sqlalche.me/e/e3q8)

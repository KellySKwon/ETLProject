# %%
import pandas as pd

#censuslink url https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?src=bkmk
#state url https://www.factmonster.com/us/postal-information/state-abbreviations-and-state-postal-codes

# %%
url = 'https://www.numbeo.com/quality-of-life/region_rankings_current.jsp?region=021'

# %%
#scrape and read as pandas df
tables = pd.read_html(url)
tables
# Out:
# [    0                                                  1
#  0 NaN  What are you looking for? Cost of Living Crime...,     0      1
#  0 NaN  Tweet,     Rank                               City  Quality of Life Index  \
#  0    NaN         Raleigh, NC, United States                 231.44
#  1    NaN         Madison, WI, United States                 207.66
#  2    NaN          Dallas, TX, United States                 201.75
#  3    NaN       Charlotte, NC, United States                 199.49
#  4    NaN          Austin, TX, United States                 198.62
#  5    NaN        Columbus, OH, United States                 197.26
#  6    NaN                     Ottawa, Canada                 195.97
#  7    NaN        San Jose, CA, United States                 194.77
#  8    NaN                   Victoria, Canada                 193.89
#  9    NaN       San Diego, CA, United States                 191.81
#  10   NaN        Richmond, VA, United States                 191.01
# ...

# %%
# read in only table info
quality_df = tables[2]
quality_df['Rank'] = [x for x in range(1,len(quality_df)+1)]

# %%
quality_df.head()
# Out:
#    Rank                          City  Quality of Life Index  \
# 0     1    Raleigh, NC, United States                 231.44
# 1     2    Madison, WI, United States                 207.66
# 2     3     Dallas, TX, United States                 201.75
# 3     4  Charlotte, NC, United States                 199.49
# 4     5     Austin, TX, United States                 198.62
#
#    Purchasing Power Index  Safety Index  Health Care Index  \
# 0                  189.71         70.73              78.10
# 1                  135.24         72.77              81.94
# 2                  185.66         51.39              67.63
# 3                  148.06         56.62              75.66
# 4                  155.59         65.31              70.89
#
#    Cost of Living Index  Property Price to Income Ratio  \
# 0                 72.73                            2.03
# 1                 65.40                            3.22
# 2                 66.71                            1.98
# ...

# %%
len(quality_df['Rank'])
# Out:
# 61

# %%
#rename columns for DB
range(1,len(quality_df))
# Out:
# range(1, 61)

# %%
len(quality_df)
# Out:
# 61

# %%
stateurl='https://www.factmonster.com/us/postal-information/state-abbreviations-and-state-postal-codes'
#scrape and read as pandas df
statedf = pd.read_html(stateurl,header=0)
statedf
# Out:
# [                State Abbreviation Postalcode
#  0             Alabama         Ala.         AL
#  1              Alaska       Alaska         AK
#  2      American Samoa          NaN         AS
#  3             Arizona        Ariz.         AZ
#  4            Arkansas         Ark.         AR
#  5          California       Calif.         CA
#  6            Colorado        Colo.         CO
#  7         Connecticut        Conn.         CT
#  8            Delaware         Del.         DE
#  9   Dist. of Columbia         D.C.         DC
#  10            Florida         Fla.         FL
#  11            Georgia          Ga.         GA
#  12               Guam         Guam         GU
#  13             Hawaii       Hawaii         HI
#  14              Idaho        Idaho         ID
#  15           Illinois         Ill.         IL
#  16            Indiana         Ind.         IN
#  17               Iowa         Iowa         IA
#  18             Kansas        Kans.         KS
# ...

# %%
#convert to df object
state_df = statedf[0]
state_df.head()
# Out:
#             State Abbreviation Postalcode
# 0         Alabama         Ala.         AL
# 1          Alaska       Alaska         AK
# 2  American Samoa          NaN         AS
# 3         Arizona        Ariz.         AZ
# 4        Arkansas         Ark.         AR
